# %%
# Dependencies
import pandas as pd

# %%
# List of file names to be combined 
data_2023 = ['Resources\JC-202306-citibike-tripdata.csv', 'Resources\JC-202307-citibike-tripdata.csv', 'Resources\JC-202308-citibike-tripdata.csv', 'Resources\JC-202309-citibike-tripdata.csv', 'Resources\JC-202310-citibike-tripdata.csv', 'Resources\JC-202311-citibike-tripdata.csv']

# Create an empty list to store each dataframe
df23_list = []

# Loop through each file in the list
for file in data_2023:
    # Read the file into a dataframe
    df23 = pd.read_csv(file)

    # Append the dataframe to the list
    df23_list.append(df23)

# Concatenate all dataframes in the list into one dataframe
df23 = pd.concat(df23_list)

# Show dataframe
df23
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1      9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2      C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3      2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4      E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                 ...            ...                  ...
# 75641  EE6CF90DF3984253   classic_bike  2023-11-22 16:20:23
# 75642  DB574978E7FABC08   classic_bike  2023-11-21 07:01:57
# 75643  E8E26D6A35E922FA   classic_bike  2023-11-14 07:51:51
# 75644  0D6ECB6E18E32C63   classic_bike  2023-11-17 08:15:06
# 75645  817DBC6302EDF681   classic_bike  2023-11-16 10:55:31
#
#                   ended_at     start_station_name start_station_id  \
# 0      2023-06-27 16:10:27                Hilltop            JC019
# 1      2023-06-24 10:55:27  Baldwin at Montgomery            JC020
# ...
